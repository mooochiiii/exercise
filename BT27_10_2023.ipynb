# %% [markdown]
# <a href="https://colab.research.google.com/github/mooochiiii/exercise/blob/main/BT27_10_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# Đọc dữ liệu nạp vào

# %%
path = '/content/USA_Housing.csv'
data = pd.read_csv(path)
data.head(10)
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
# 5      80175.754159             4.988408                   6.104512
# 6      64698.463428             6.025336                   8.147760
# 7      78394.339278             6.989780                   6.620478
# 8      59927.660813             5.362126                   6.393121
# 9      81885.927184             4.423672                   8.167688
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# ...

# %% [markdown]
# Tối ưu hoá bằng thuật toán Linear Regression

# %%
X = data[['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
       'Avg. Area Number of Bedrooms', 'Area Population']]
y = data['Price']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=101)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
def linear_regression_fit(X, y):
  ones = np.ones((X.shape[0], 1))
  X = np.hstack((ones, X))
  LR = np.linalg.inv(X.T.dot(X)).dot(X.T).dot(y)
  return LR

# %%
LR = linear_regression_fit(X_train_scaled, y_train)

# %%
intercept = LR[0]
coefficients = LR[1:]

# %%
equation = f"y = {intercept} + " + " + ".join([f"{coef} * X{i+1}" for i, coef in enumerate(coefficients)])
print(equation)
# Out:
# y = 1228450.3183816888 + 227623.46356492088 * X1 + 160615.53988470687 * X2 + 121847.23968261963 * X3 + 2752.1116465314226 * X4 + 151227.42361999615 * X5

# %% [markdown]
# Tối ưu hoá bằng thuật toán Support Vector Machine
